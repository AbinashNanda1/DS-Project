# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
df['SepalLengthCm'].hist()

# %%
df['SepalWidthCm'].hist()

# %%
df['PetalLengthCm'].hist()

# %%
df['PetalWidthCm'].hist()

# %%
plt.figure(figsize=(5,6))
plt.scatter(x='SepalLengthCm',y='SepalWidthCm',data=df[df.Species=='Iris-versicolor'],c='red',label='Iris-versicolor')
plt.scatter(x='SepalLengthCm',y='SepalWidthCm',data=df[df.Species=='Iris-virginica'],c='yellow',label='Iris-virginica')
plt.scatter(x='SepalLengthCm',y='SepalWidthCm',data=df[df.Species=='Iris-setosa'],c='blue',label='Iris-setosa')
plt.xlabel('SepalLength')
plt.ylabel('SepalWidth')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,6))
plt.scatter(x='PetalLengthCm',y='PetalWidthCm',data=df[df.Species=='Iris-versicolor'],c='red',label='Iris-versicolor')
plt.scatter(x='PetalLengthCm',y='PetalWidthCm',data=df[df.Species=='Iris-virginica'],c='yellow',label='Iris-virginica')
plt.scatter(x='PetalLengthCm',y='PetalWidthCm',data=df[df.Species=='Iris-setosa'],c='blue',label='Iris-setosa')
plt.xlabel('PetalLength')
plt.ylabel('PetalWidth')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,6))
plt.scatter(x='SepalWidthCm',y='PetalWidthCm',data=df[df.Species=='Iris-versicolor'],c='red',label='Iris-versicolor')
plt.scatter(x='SepalWidthCm',y='PetalWidthCm',data=df[df.Species=='Iris-virginica'],c='yellow',label='Iris-virginica')
plt.scatter(x='SepalWidthCm',y='PetalWidthCm',data=df[df.Species=='Iris-setosa'],c='blue',label='Iris-setosa')
plt.xlabel('SepalWIdth')
plt.ylabel('PetalWidth')
plt.legend()
plt.show()

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
corr =df.corr()
sns.heatmap(corr,annot=True)

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

# %%
df['Species'] = le.fit_transform(df['Species'])

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %% [markdown]
# ## Model Training

# %% [markdown]
# ## DecisionTree

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns=['Species'])
y = df['Species']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree,export_text
from sklearn.metrics import plot_confusion_matrix
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print('Model Accuracy:',model.score(x_test,y_test)*100)
# Out:
# Model Accuracy: 100.0

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
prediction = model.predict(x_test)

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        16
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print('Model Accuracy:',model.score(x_test,y_test))
# Out:
# Model Accuracy: 1.0
